# %%
print("Start Quiz:")
print("--------------")
#Quiz question 1:
x = bool(True) + bool(True) - bool(False)

print("Quiz answer 1:" + " " + str(x))
print("--------------")

#Quiz question 2:
y = True
y = y & y
y = y | (y - y)
print("Quiz answer 2:" + " " + str(y))
print("--------------")

#Quiz question 5:
string = "E. Coli"
z = string[2]
print("Quiz answer 5:" + " " + str(z))
print("--------------")

#Quiz question 6:
string = "I Bove python"
#string[2]="L"
#print(string)

#Quiz question 7:
#Variable named "Medication", assigned the given value of 5 (integer):
Medication = 5
#setting variable w to the type of variable "Medication" is:
w = type(Medication)
#printing out the type of variable "Medication" is by printing w:
print("Quiz answer 7:" + " " + str(w))
print("--------------")

#Quiz question 8:
#Set Susan's weight in kg as a float.
Susan_weight = 60.0
#Set Susan's height in m as a float.
Susan_height = 1.58
#Calculate BMI by dividing weight in kg by her height squared in m.
Susan_BMI_unrounded = Susan_weight/((Susan_height)*(Susan_height))
#Round the output for a simpler output.
Susan_BMI_rounded = round(Susan_BMI_unrounded, 2)
print("Quiz answer 8:" + " " + str(Susan_BMI_rounded))
print("--------------")

#Quiz question 9:
print("Quiz question 9:")
z = 3 + 6
print(z)
w = "string 1" + " and " + "string 2"
print (w)
print("--------------")

#Quiz question 10:
a = str(7)
b = str(3)
c = a + b
print("Quiz answer 10:" + " " + c)
print("--------------")
print("End Quiz")
print("--------------")
print("--------------")
# Out:
# Start Quiz:
# --------------
# Quiz answer 1: 2
# --------------
# Quiz answer 2: 1
# --------------
# Quiz answer 5:
# --------------
# Quiz answer 7: <class 'int'>
# --------------
# Quiz answer 8: 24.03
# --------------
# Quiz question 9:
# 9
# string 1 and string 2
# --------------
# Quiz answer 10: 73
# --------------
# End Quiz
# --------------
# --------------
